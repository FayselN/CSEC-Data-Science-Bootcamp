# %% [markdown]
# <a href="https://colab.research.google.com/github/FayselN/CSEC-Data-Science-Bootcamp/blob/main/data_science_club_answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is the difference between a list, a dictionary, and a NumPy array? Give one example of each.
#
# # **List (Python's Built-in List)**
#
# A list is an ordered collection of items, where the items can be of any type (e.g., integers, strings, floats). It is mutable, meaning you can modify it after creation.
# # Characteristics of a List:
# Ordered: The order of elements is preserved.
# Mutable: You can change, add, or remove elements.
# Heterogeneous: It can hold elements of different types (e.g., integers, strings, etc.).
#
# # **2.Dictionary (Python's Built-in Dictionary)**
# A dictionary is an unordered collection of key-value pairs. Each key is unique and associated with a value. Dictionaries are mutable, so you can add, remove, or modify the key-value pairs.
# # Characteristics of a Dictionary:
# Unordered: Keys don’t have a specific order (until Python 3.7, where insertion order is preserved).
# Mutable: You can add, modify, or remove elements.
# Key-Value Pairs: Each item consists of a key and a corresponding value.
#
# # 3. NumPy Array (NumPy Library)
# A NumPy array is a homogeneous, fixed-size array used in numerical computing. It is part of the NumPy library, which is widely used in data science for efficient numerical calculations.
# # Characteristics of NumPy Arrays:
# **Homogeneous**: All elements are of the same type (e.g., all integers or all floats).
#
# **Fixed** Size: Once created, the size of the array cannot be changed.
# **Efficient**: Provides fast operations for large datasets, unlike lists.
#
# **Multidimensional**: Can handle arrays with multiple dimensions (like matrices, vectors, etc.).
# # When to Use Each?
# 1. Lists:
# Use lists when you have a collection of items where order matters and the items may vary in type.
# 2. Dictionaries:
# Use dictionaries when you need to store key-value pairs (e.g., a mapping between names and ages).
# 3. NumPy Arrays: Use NumPy arrays for numerical data (especially when performance is key and you need operations like matrix multiplication, vectorization, etc.).

# %%
 # Q1.Example(list):
my_list = [1, 2, 3, 'hello', 4.5]
print(my_list)  # Output: [1, 2, 3, 'hello', 4.5]
# Accessing list items:
print(my_list[0])  # Output: 1
print(my_list[3])  # Output: 'hello'
# Modifying a list:
my_list[2] = 10
print(my_list)  # Output: [1, 2, 10, 'hello', 4.5]
# Example(dictionary):
my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}
print(my_dict)  # Output: {'name': 'John', 'age': 25, 'city': 'New York'}
# Accessing values by key:
print(my_dict['name'])  # Output: 'John'
# Modifying a dictionary:
my_dict['age'] = 26
print(my_dict)  # Output: {'name': 'John', 'age': 26, 'city': 'New York'}
# Adding a new key-value pair:
my_dict['job'] = 'Engineer'
print(my_dict)  # Output: {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Engineer'}
 #Example(numpy array):
import numpy as np
# Create a NumPy array
my_array = np.array([1, 2, 3, 4])
print(my_array)  # Output: [1 2 3 4]

# Operations on NumPy array
print(my_array * 2)  # Output: [2 4 6 8]
# Create a 2D NumPy array (Matrix)
my_matrix = np.array([[1, 2], [3, 4]])
print(my_matrix)
# Output:
# [[1 2]
#  [3 4]]
# Accessing elements:
print(my_matrix[1, 0])  # Output: 3

# %%
#2.
def squares(my_list):
  s=[]
  for i in range(len(my_list)):
    if my_list[i]%2==0:
       s.append(my_list[i]**2)
  return s

my_list=[10,11,12,14]

k=squares(my_list)
print (k)
# Out:
# [100, 144, 196]

# %%
#3.
x = [1, 2, 3]
y = x
y.append(4)
print(x)
#Output
[1, 2, 3, 4]

# %% [markdown]
# 3.Why?
#
# In Python, lists are mutable objects, and variables hold references to these objects.
#
# When you do y = x, both x and y point to the same list in memory. So when you do y.append(4), you're modifying the same list that x refers to.
# Hence, print(x) will show the modified list: [1, 2, 3, 4].

# %% [markdown]
# 4. What does .shape() and .describe() tell you about a pandas DataFrame? Show using an example.
# # What is .shape()?
# .shape gives you:
# The number of rows and columns in a DataFrame.
# It returns a tuple: (rows, columns)
# # What is .describe()?
# .describe() gives you:
# Summary statistics of numeric columns like:
# -count,mean,std (standard deviation),min,25%, 50%, 75% (quartiles) ,max

# %%
#4.example4
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Ali', 'Sara', 'John'],
    'Age': [25, 30, 22],
    'Salary': [5000, 6000, 5500]
}

df = pd.DataFrame(data)

# Shape of the DataFrame
print(df.shape)
#output:  (3, 3)
# Out:
#      <input type="file" id="files-a463a594-0f1a-4c40-99e2-80d77142ccc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a463a594-0f1a-4c40-99e2-80d77142ccc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#5.
from google.colab import files
files.upload()

import pandas as pd
df = pd.read_csv('airtravel.csv')
print(df.head())
# Out:
#      <input type="file" id="files-5266da63-f2c0-4a20-94d5-67a2738e4d3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5266da63-f2c0-4a20-94d5-67a2738e4d3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 5.The data shows monthly air travel statistics across multiple years (e.g., 1958, 1959, 1960).
#
# Rows = months (JAN, FEB, etc.)
#
# Columns = years
#
# It's in wide format
#
# Useful for analyzing trends in air passenger numbers over time.

# %%
#6.
import pandas as pd

df = pd.read_csv('airtravel.csv')
# Sum across all years for each month
df['Total'] = df.iloc[:, 1:].sum(axis=1)

# Find the row (month) with the highest total
max_month = df.loc[df['Total'].idxmax(), 'Month']
print("Month with highest total passengers:", max_month)

min_1958 = df.loc[df['1958'].idxmin(), 'Month']
print("Month with lowest passengers in 1958:", min_1958)

# %% [markdown]
# 7.
# .groupby() in pandas is used to group rows based on values in one or more columns — like saying “group by department,” or “group by category,” then perform calculations like sum, mean, count, etc.
# It groups similar values together and allows you to apply functions to each group.

# %%
#7.example
import pandas as pd

# Dummy data: students and their scores by class
data = {
    'Class': ['A', 'A', 'B', 'B', 'C', 'C'],
    'Student': ['Ali', 'Sara', 'John', 'Liya', 'Noah', 'Emma'],
    'Score': [85, 90, 78, 88, 92, 95]
}

df = pd.DataFrame(data)

# Group by Class and get average score
grouped = df.groupby('Class')['Score'].mean()
print(grouped)

# %%
#8.
import seaborn as sns
import pandas as pd

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Count missing values in each column
missing = titanic.isnull().sum()

print(missing)

# %%
#9
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
titanic = sns.load_dataset('titanic')

# Plot histogram of Age
titanic["age"].hist(bins=20)
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.title("Age Distribution of Titanic Passengers")
plt.show()

# %% [markdown]
# 9.What Shape Do You See?
# The distribution is right-skewed (positively skewed)
#
# Most passengers are young adults
#
# Fewer older passengers, and some kids and infants too
# What Might Be the Reason for the Skew?
# There were more young people and middle-aged aboard the Titanic.
#
# Fewer elderly people traveled back then due to:
#
# Cost
#
# Physical limitations
#
# Life expectancy being lower in the early 1900s
#
# Children and infants were also present, especially in families

# %% [markdown]
# 10.It means the values are spread out far from the mean (average).
#
# There’s high variability or inconsistency in the data.
#
# The data is less consistent.
#
#  On the other hand:
# Low std dev means the data is closer to the average (more consistent).

# %%
import pandas as pd

# Create two lists
low_std = [50, 51, 50, 49, 50, 50, 51, 49, 50]
high_std = [10, 90, 30, 100, 70, 20, 80, 40, 60]

# Put them in a DataFrame
df = pd.DataFrame({
    'Low_StdDev': low_std,
    'High_StdDev': high_std
})

# Calculate and display standard deviation
print("Standard Deviations:")
print(df.std())

# Optional: Display the data
print("\nData:")
print(df)

# %% [markdown]
# 11.
# 1. Medical Diagnosis
# Problem: Missing patient data like blood pressure, age, or medical history.
#
# Impact: It can lead to wrong diagnoses, unsafe treatments, or biased clinical studies.
#
# Example: If older patients are more likely to have missing data, the model might think diseases mostly affect young people.
#
# 2. Loan Approval in Banking
# Problem: Missing financial data such as income, credit history, or employment details.
#
# Impact: Banks might approve risky loans or reject trustworthy clients, leading to financial losses or unfair decisions.
#
# Example: A missing income field might cause a loan rejection even if the person qualifies.
